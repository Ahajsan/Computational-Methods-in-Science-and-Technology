# %%
import numpy as np
import matplotlib.pyplot as plt

def zero_function(x):
    return x ** 2 - 25 * np.sin(x) ** 10
    
def zero_aprx():
    return 0.754774

def ro():
    return [1e-8, 1e-12, 1e-16]

# %%
def next_step(a,b,f):
    return b - (f(b) * (b - a))/(f(b) - f(a))

def print_siecznych_metoda(a,b,N,e,method):
    start = (a,b)
    max_iterations = N
    f = zero_function
    
    if f(a) * f(b) == 0:
        return a if f(a) == 0 else b
 
    x = next_step(a, b, f)
    iteration = 1
    prev_x = x

    while iteration < max_iterations:

        
        if method == 1 and abs(f(x)) < e:
            return f"Przedział: {start}, Wynik: {x}, Iteracje: {iteration-1}, Różnica: {abs(zero_aprx() - x):}"

        if f(x) * f(a) < 0:
            b = x
        else:
            a = x

        new_x = next_step(a, b, f)
        if method == 2 and abs(new_x - x) < e:
            return f"Przedział: {start}, Wynik: {x}, Iteracje: {iteration-1}, Różnica: {abs(zero_aprx() - x):}"
            
        x = new_x
        iteration += 1
    return "maksymalna ilosć iteracji osiaągnięta", f"Przedział: {start}, Wynik: {x}, Różnica: {abs(zero_aprx() - x):}"
        

r = ro()
for e in r:
    a = 0.4
    b = 2
    print(e)
    while True:
        print(print_siecznych_metoda(a,b,1000,e,1))
        b -= 0.1
        if b < a:
            print()
            break
# Out:
# 1e-08
# Przedział: (0.4, 2), Wynik: 0.7547744761470285, Iteracje: 9, Różnica: 4.7614702858300717e-07
# Przedział: (0.4, 1.9), Wynik: 0.7547744747662337, Iteracje: 37, Różnica: 4.7476623377118443e-07
# Przedział: (0.4, 1.7999999999999998), Wynik: 0.7547744745566081, Iteracje: 66, Różnica: 4.7455660812101286e-07
# Przedział: (0.4, 1.6999999999999997), Wynik: 0.7547744742941067, Iteracje: 95, Różnica: 4.742941067670259e-07
# Przedział: (0.4, 1.5999999999999996), Wynik: 0.7547744739893526, Iteracje: 119, Różnica: 4.7398935265619e-07
# Przedział: (0.4, 1.4999999999999996), Wynik: 0.7547744742841863, Iteracje: 135, Różnica: 4.7428418636918934e-07
# Przedział: (0.4, 1.3999999999999995), Wynik: 0.7547744741198702, Iteracje: 137, Różnica: 4.7411987025292035e-07
# Przedział: (0.4, 1.2999999999999994), Wynik: 0.7547744742340955, Iteracje: 127, Różnica: 4.742340955488089e-07
# Przedział: (0.4, 1.1999999999999993), Wynik: 0.7547744740135669, Iteracje: 106, Różnica: 4.74013566953424e-07
# Przedział: (0.4, 1.0999999999999992), Wynik: 0.7547744744125556, Iteracje: 81, Różnica: 4.74412555684367e-07
# Przedział: (0.4, 0.9999999999999992), Wynik: 0.7547744740180674, Iteracje: 54, Różnica: 4.7401806746449893e-07
# Przedział: (0.4, 0.8999999999999992), Wynik: 0.7547744739893003, Iteracje: 31, Różnica: 4.7398930036468556e-07
# Przedział: (0.4, 0.7999999999999993), Wynik: 0.7547744750754395, Iteracje: 13, Różnica: 4.7507543954328213e-07
# ('maksymalna ilosć iteracji osiaągnięta', 'Przedział: (0.4, 0.6999999999999993), Wynik: 0.013555041324003314, Różnica: 0.7412189586759966')
# ('maksymalna ilosć iteracji osiaągnięta', 'Przedział: (0.4, 0.5999999999999993), Wynik: 0.0004609885695899818, Różnica: 0.75431301143041')
# ('maksymalna ilosć iteracji osiaągnięta', 'Przedział: (0.4, 0.49999999999999933), Wynik: 0.00046704665540353574, Różnica: 0.7543069533445964')
#
# 1e-12
# Przedział: (0.4, 2), Wynik: 0.7547744761481324, Iteracje: 10, Różnica: 4.7614813247776056e-07
# Przedział: (0.4, 1.9), Wynik: 0.7547744761479973, Iteracje: 51, Różnica: 4.7614799736361846e-07
# Przedział: (0.4, 1.7999999999999998), Wynik: 0.7547744761479727, Iteracje: 92, Różnica: 4.761479727166673e-07
# Przedział: (0.4, 1.6999999999999997), Wynik: 0.7547744761479337, Iteracje: 133, Różnica: 4.7614793374783915e-07
# Przedział: (0.4, 1.5999999999999996), Wynik: 0.754774476147926, Iteracje: 168, Różnica: 4.761479260873003e-07
# Przedział: (0.4, 1.4999999999999996), Wynik: 0.7547744761479327, Iteracje: 190, Różnica: 4.761479327486384e-07
# Przedział: (0.4, 1.3999999999999995), Wynik: 0.754774476147933, Iteracje: 194, Różnica: 4.7614793308170533e-07
# Przedział: (0.4, 1.2999999999999994), Wynik: 0.7547744761479394, Iteracje: 180, Różnica: 4.7614793940997657e-07
# Przedział: (0.4, 1.1999999999999993), Wynik: 0.7547744761479211, Iteracje: 151, Różnica: 4.7614792120231897e-07
# Przedział: (0.4, 1.0999999999999992), Wynik: 0.7547744761479367, Iteracje: 115, Różnica: 4.761479367454413e-07
# Przedział: (0.4, 0.9999999999999992), Wynik: 0.7547744761479511, Iteracje: 78, Różnica: 4.7614795117834063e-07
# Przedział: (0.4, 0.8999999999999992), Wynik: 0.7547744761479275, Iteracje: 45, Różnica: 4.761479275305902e-07
# Przedział: (0.4, 0.7999999999999993), Wynik: 0.754774476148025, Iteracje: 19, Różnica: 4.7614802500817177e-07
# ('maksymalna ilosć iteracji osiaągnięta', 'Przedział: (0.4, 0.6999999999999993), Wynik: 0.013555041324003314, Różnica: 0.7412189586759966')
# ('maksymalna ilosć iteracji osiaągnięta', 'Przedział: (0.4, 0.5999999999999993), Wynik: 0.0004609885695899818, Różnica: 0.75431301143041')
# ('maksymalna ilosć iteracji osiaągnięta', 'Przedział: (0.4, 0.49999999999999933), Wynik: 0.00046704665540353574, Różnica: 0.7543069533445964')
#
# 1e-16
# Przedział: (0.4, 2), Wynik: 0.7547744761481325, Iteracje: 12, Różnica: 4.7614813258878286e-07
# ('maksymalna ilosć iteracji osiaągnięta', 'Przedział: (0.4, 1.9), Wynik: 0.7547744761481323, Różnica: 4.7614813236673825e-07')
# ('maksymalna ilosć iteracji osiaągnięta', 'Przedział: (0.4, 1.7999999999999998), Wynik: 0.7547744761481321, Różnica: 4.7614813214469365e-07')
# ('maksymalna ilosć iteracji osiaągnięta', 'Przedział: (0.4, 1.6999999999999997), Wynik: 0.7547744761481323, Różnica: 4.7614813236673825e-07')
# ('maksymalna ilosć iteracji osiaągnięta', 'Przedział: (0.4, 1.5999999999999996), Wynik: 0.7547744761481322, Różnica: 4.7614813225571595e-07')
# ('maksymalna ilosć iteracji osiaągnięta', 'Przedział: (0.4, 1.4999999999999996), Wynik: 0.7547744761481321, Różnica: 4.7614813214469365e-07')
# ('maksymalna ilosć iteracji osiaągnięta', 'Przedział: (0.4, 1.3999999999999995), Wynik: 0.7547744761481322, Różnica: 4.7614813225571595e-07')
# ('maksymalna ilosć iteracji osiaągnięta', 'Przedział: (0.4, 1.2999999999999994), Wynik: 0.7547744761481323, Różnica: 4.7614813236673825e-07')
# ('maksymalna ilosć iteracji osiaągnięta', 'Przedział: (0.4, 1.1999999999999993), Wynik: 0.7547744761481319, Różnica: 4.7614813192264904e-07')
# ('maksymalna ilosć iteracji osiaągnięta', 'Przedział: (0.4, 1.0999999999999992), Wynik: 0.7547744761481323, Różnica: 4.7614813236673825e-07')
# ('maksymalna ilosć iteracji osiaągnięta', 'Przedział: (0.4, 0.9999999999999992), Wynik: 0.7547744761481323, Różnica: 4.7614813236673825e-07')
# ('maksymalna ilosć iteracji osiaągnięta', 'Przedział: (0.4, 0.8999999999999992), Wynik: 0.7547744761481323, Różnica: 4.7614813236673825e-07')
# Przedział: (0.4, 0.7999999999999993), Wynik: 0.7547744761481325, Iteracje: 25, Różnica: 4.7614813258878286e-07
# ('maksymalna ilosć iteracji osiaągnięta', 'Przedział: (0.4, 0.6999999999999993), Wynik: 0.013555041324003314, Różnica: 0.7412189586759966')
# ('maksymalna ilosć iteracji osiaągnięta', 'Przedział: (0.4, 0.5999999999999993), Wynik: 0.0004609885695899818, Różnica: 0.75431301143041')
# ('maksymalna ilosć iteracji osiaągnięta', 'Przedział: (0.4, 0.49999999999999933), Wynik: 0.00046704665540353574, Różnica: 0.7543069533445964')

# %%
def zero_derative_function(x):
    return 2*x - 250 * np.cos(x) * np.sin(x) ** 9

def next_point(x, f, d, max_iterations, iteration):
    if iteration >= max_iterations:
        return None  
    return x - f(x) / d(x)  
    
def Newton(x, N, r, method):
    start = x
    max_iterations = N
    iteration = 0
    f = zero_function
    d = zero_derative_function
    n = next_point
    
    while iteration < max_iterations:
        iteration += 1
        if method == 1 and abs(f(x)) < r:
            return f"Przedział: {start}, Wynik: {x}, Iteracje: {iteration}, Różnica: {abs(zero_aprx() - x)}"
        
        next_x = next_point(x, f, d, max_iterations, iteration)
        if next_x is None:
            return "maksymalna ilość iteracji osiągnięta", f"Przedział: {start}, Wynik: {x}, Różnica: {abs(zero_aprx() - x)}"
        
        if method == 2 and abs(f(x) - f(next_x)) < r:
            return f"Przedział: {start}, Wynik: {x}, Iteracje: {iteration}, Różnica: {abs(zero_aprx() - x)}"
        
        x = next_x
    
    return "maksymalna ilość iteracji osiągnięta", f"Przedział: {start}, Wynik: {x}, Różnica: {abs(zero_aprx() - x)}"



r = ro()
for e in r:
    print(e)
    z = 0.4
    while True:
        print(Newton(z,1000,e,1))
        z += 0.1
        if z > 2.1:
            print()
            break
# Out:
# 1e-08
# Przedział: 0.4, Wynik: 9.278883835457552e-05, Iteracje: 13, Różnica: 0.7546812111616453
# Przedział: 0.5, Wynik: 8.242098051093968e-05, Iteracje: 13, Różnica: 0.754691579019489
# Przedział: 0.6, Wynik: 4.829912922919889, Iteracje: 12, Różnica: 4.075138922919889
# Przedział: 0.7, Wynik: 0.7547744761481341, Iteracje: 6, Różnica: 4.761481341430951e-07
# Przedział: 0.7999999999999999, Wynik: 0.754774476151935, Iteracje: 5, Różnica: 4.761519351026422e-07
# Przedział: 0.8999999999999999, Wynik: 0.7547744762311492, Iteracje: 6, Różnica: 4.762311492934046e-07
# Przedział: 0.9999999999999999, Wynik: 0.7547744761489487, Iteracje: 7, Różnica: 4.7614894871372826e-07
# Przedział: 1.0999999999999999, Wynik: 0.7547744774859473, Iteracje: 7, Różnica: 4.774859473366533e-07
# Przedział: 1.2, Wynik: 0.7547744761481385, Iteracje: 8, Różnica: 4.761481385839872e-07
# Przedział: 1.3, Wynik: 0.7547744761481356, Iteracje: 8, Różnica: 4.761481356974073e-07
# Przedział: 1.4000000000000001, Wynik: 0.7547744761481326, Iteracje: 7, Różnica: 4.7614813269980516e-07
# Przedział: 1.5000000000000002, Wynik: -9.518424898907228e-05, Iteracje: 11, Różnica: 0.754869184248989
# Przedział: 1.6000000000000003, Wynik: 4.829912922920369, Iteracje: 9, Różnica: 4.0751389229203685
# Przedział: 1.7000000000000004, Wynik: 2.137462332178803, Iteracje: 7, Różnica: 1.382688332178803
# Przedział: 1.8000000000000005, Wynik: 2.1374623321788047, Iteracje: 5, Różnica: 1.3826883321788048
# Przedział: 1.9000000000000006, Wynik: 2.1374623321175577, Iteracje: 5, Różnica: 1.3826883321175578
# Przedział: 2.0000000000000004, Wynik: 2.137462332177679, Iteracje: 5, Różnica: 1.382688332177679
#
# 1e-12
# Przedział: 0.4, Wynik: 7.249127996451212e-07, Iteracje: 20, Różnica: 0.7547732750872003
# Przedział: 0.5, Wynik: 6.439139102417163e-07, Iteracje: 20, Różnica: 0.7547733560860898
# Przedział: 0.6, Wynik: 4.8299129229196955, Iteracje: 13, Różnica: 4.075138922919695
# Przedział: 0.7, Wynik: 0.7547744761481341, Iteracje: 6, Różnica: 4.761481341430951e-07
# Przedział: 0.7999999999999999, Wynik: 0.7547744761481324, Iteracje: 6, Różnica: 4.7614813247776056e-07
# Przedział: 0.8999999999999999, Wynik: 0.7547744761481325, Iteracje: 7, Różnica: 4.7614813258878286e-07
# Przedział: 0.9999999999999999, Wynik: 0.7547744761481324, Iteracje: 8, Różnica: 4.7614813247776056e-07
# Przedział: 1.0999999999999999, Wynik: 0.7547744761481325, Iteracje: 8, Różnica: 4.7614813258878286e-07
# Przedział: 1.2, Wynik: 0.7547744761481385, Iteracje: 8, Różnica: 4.761481385839872e-07
# Przedział: 1.3, Wynik: 0.7547744761481356, Iteracje: 8, Różnica: 4.761481356974073e-07
# Przedział: 1.4000000000000001, Wynik: 0.7547744761481326, Iteracje: 7, Różnica: 4.7614813269980516e-07
# Przedział: 1.5000000000000002, Wynik: -7.436269452271272e-07, Iteracje: 18, Różnica: 0.7547747436269452
# Przedział: 1.6000000000000003, Wynik: 4.8299129229196955, Iteracje: 10, Różnica: 4.075138922919695
# Przedział: 1.7000000000000004, Wynik: 2.137462332178803, Iteracje: 7, Różnica: 1.382688332178803
# Przedział: 1.8000000000000005, Wynik: 2.1374623321788047, Iteracje: 5, Różnica: 1.3826883321788048
# Przedział: 1.9000000000000006, Wynik: 2.137462332178805, Iteracje: 6, Różnica: 1.3826883321788053
# Przedział: 2.0000000000000004, Wynik: 2.137462332178805, Iteracje: 6, Różnica: 1.3826883321788053
#
# 1e-16
# Przedział: 0.4, Wynik: 5.66338124722751e-09, Iteracje: 27, Różnica: 0.7547739943366187
# Przedział: 0.5, Wynik: 5.030577423763408e-09, Iteracje: 27, Różnica: 0.7547739949694225
# Przedział: 0.6, Wynik: 4.8299129229196955, Iteracje: 13, Różnica: 4.075138922919695
# Przedział: 0.7, Wynik: 0.7547744761481325, Iteracje: 7, Różnica: 4.7614813258878286e-07
# ('maksymalna ilość iteracji osiągnięta', 'Przedział: 0.7999999999999999, Wynik: 0.7547744761481324, Różnica: 4.7614813247776056e-07')
# Przedział: 0.8999999999999999, Wynik: 0.7547744761481325, Iteracje: 7, Różnica: 4.7614813258878286e-07
# ('maksymalna ilość iteracji osiągnięta', 'Przedział: 0.9999999999999999, Wynik: 0.7547744761481324, Różnica: 4.7614813247776056e-07')
# Przedział: 1.0999999999999999, Wynik: 0.7547744761481325, Iteracje: 8, Różnica: 4.7614813258878286e-07
# ('maksymalna ilość iteracji osiągnięta', 'Przedział: 1.2, Wynik: 0.7547744761481324, Różnica: 4.7614813247776056e-07')
# ('maksymalna ilość iteracji osiągnięta', 'Przedział: 1.3, Wynik: 0.7547744761481326, Różnica: 4.7614813269980516e-07')
# ('maksymalna ilość iteracji osiągnięta', 'Przedział: 1.4000000000000001, Wynik: 0.7547744761481324, Różnica: 4.7614813247776056e-07')
# Przedział: 1.5000000000000002, Wynik: -5.809585509586931e-09, Iteracje: 25, Różnica: 0.7547740058095854
# Przedział: 1.6000000000000003, Wynik: 4.8299129229196955, Iteracje: 10, Różnica: 4.075138922919695
# Przedział: 1.7000000000000004, Wynik: 2.137462332178805, Iteracje: 8, Różnica: 1.3826883321788053
# Przedział: 1.8000000000000005, Wynik: 2.137462332178805, Iteracje: 6, Różnica: 1.3826883321788053
# Przedział: 1.9000000000000006, Wynik: 2.137462332178805, Iteracje: 6, Różnica: 1.3826883321788053
# Przedział: 2.0000000000000004, Wynik: 2.137462332178805, Iteracje: 6, Różnica: 1.3826883321788053

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definicja funkcji
def f(x):
    return x ** 2 - 25 * np.sin(x) ** 10

# Przedział i siatka punktów
x = np.linspace(0.4, 2.0, 1000)
y = f(x)

# Rysowanie wykresu
plt.figure(figsize=(10, 6))
plt.plot(x, y, label=r'$f(x) = x^2 - 25 \cdot \sin^{10}(x)$', color='blue')
plt.axhline(0, color='gray', linestyle='--')
plt.title("sd")
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
